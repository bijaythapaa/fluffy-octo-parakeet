# %% [markdown]
# # Pandas Built-in Data-Visualization
# we will learn about pandas built-in capabilities for data visualization! It's built-off of matplotlib, but it baked into pandas for easier usage!

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1')
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1 = pd.read_csv('df1',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A']
# Out:
# 2000-01-01    1.339091
# 2000-01-02   -0.774984
# 2000-01-03   -0.921037
# 2000-01-04   -1.738808
# 2000-01-05   -0.905980
#                 ...
# 2002-09-22    1.013897
# 2002-09-23   -0.642659
# 2002-09-24    0.370136
# 2002-09-25    0.183339
# 2002-09-26    0.775133
# Name: A, Length: 1000, dtype: float64

# %%
# df1['A'].hist()
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Style Sheets
#
# Matplotlib has style sheets we can use to make your plots look a little nicer. These style sheets include plot_bmh,plot_fivethirtyeight,plot_ggplot and more. They basically create a set of style rules that your plots follow. I recommend using them, they make all our plots have the same look and feel more professional. We can even create our own if we want our company's plots to all have the same look (it is a bit tedious to create on though).
#
# Here is how to use them.
#
# Before plt.style.use() our plots look like this:

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Call the style:

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# now our plot looks like this:

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('bmh')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('bmh')

# %% [markdown]
# ## Plot Types
# There are several plot types built-in to pandas, most of them statistical plots by nature:
# - df.plot.area
# - df.plot.barh
# - df.plot.density
# - df.plot.hist
# - df.plot.line
# - df.plot.scatter
# - df.plot.bar
# - df.plot.box
# - df.plot.hexbin
# - df.plot.kde
# - df.plot.pie
#
# We can also just call df.plot(kind='hist') or replace that kind argument with any of the key terms shown in the list above (e.g. 'box','barh', etc..)

# %% [markdown]
# ### Area

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df2.plot(kind='area',alpha=0.8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Barplots

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Histogram

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Line plots

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
# df1.plot.line(x=df1.index,y='B')
df1.plot.line(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A'>

# %%
df1.plot.line(x='A',y='B',figsize=(12,3),lw=1)
# Out:
# <AxesSubplot:xlabel='A'>

# %% [markdown]
# ### Scatter Plot

# %%
df1.plot.scatter(x='A',y='C')
# Out:
# <AxesSubplot:xlabel='A', ylabel='C'>

# %% [markdown]
# We can use c='' parameter to color based off another column value Use cmap to indicate colormap to use. For all the colormaps, check out: http://matplotlib.org/users/colormaps.html

# %%
df1.plot.scatter(x='A',y='C',c='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='C'>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='Set2')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# Or use s to indicate size based off another column. s parameter needs to be an array, not just the name of a column:

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# ### Box Plot

# %%
df2.plot.box() # Can also pass a by= argument for groupby
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Hexagonal Bin Plot
# Useful for Bivariate Data, alternative to scatterplot:

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
# df.head()
df.plot.hexbin(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# ### Kernal Density Estimate Plot

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Density
# (same as kde)

# %%
df2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# That's it! Now we can see why this method of plotting will be a lot easier to use than full-on matplotlib, it balances ease of use with control over the figure. A lot of the plot calls also accept additional arguments of their parent matplotlib plt. call.

# %% [markdown]
# ### Great Job !!
