# %% [markdown]
# # Advanced Concepts on Matplotlib
# we'll see some more advanced topics which we won't usually use as often.
# we can always reference the documentation for more resources!

# %% [markdown]
# ### Logarithmic Scale

# %% [markdown]
# It is also possible to set logarithmic scale for one or both axes.
# This functionality is in fact only one application of a more general transformation system in Matplotlib. Each of the axes' scales are set seperately using '.set_xscale()' and '.set_yscale()' methods which accept one parameter (with the value "log" in this case):

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
fig, axes = plt.subplots(1,2,figsize=(10,4))

axes[0].plot(x,x**2,x,np.exp(x))
axes[0].set_title("Normal Scale")

axes[1].plot(x,x**2,x,np.exp(x))
axes[1].set_yscale('log')
axes[1].set_title("Logarathmic Scale")
# Out:
# Text(0.5, 1.0, 'Logarathmic Scale')

# %% [markdown]
# ### Axis Grid
# with the ".grid()" method in axis object, we can turn off and on grid lines. we can also customize the apperance of the grid lines using the same keyword arguments as .plot() function.

# %%
fig, axes = plt.subplots(1,2,figsize=(10,4))

# default grid appearance
axes[0].plot(x,x**2,x,x**3,lw=2,)
axes[0].grid(True)

# custom grid appearance
axes[1].plot(x,x**2,x,x**3,lw=2)
axes[1].grid(color='b',alpha=0.5,ls='dashed',lw=0.5)

# %% [markdown]
# more...
